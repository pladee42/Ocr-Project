# %%
import pythainlp
from pythainlp import sent_tokenize, word_tokenize
from pythainlp import word_tokenize, Tokenizer
from pythainlp.util.trie import Trie, dict_trie
from pythainlp.corpus.common import thai_words
from pythainlp.util import normalize
from pythainlp.tokenize import word_tokenize
import pandas as pd
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_stock = pd.read_excel('input/ai_mapping_stock.xlsx',sheet_name='Stock')[["OtherDescription","SKUCode"]]
df_stock.head()
# Out:
#                                     OtherDescription                SKUCode
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000027
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000090
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000042
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000034
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...  1-GDS-HYGIE-000000058

# %%
df_item = pd.read_excel('input/ai_mapping_stock.xlsx',sheet_name='Item')[["SKUCode","Quantity"]]
df_item.head()
# Out:
#                  SKUCode  Quantity
# 0  1-GDS-HYGIE-000000031       464
# 1  1-GDS-HYGIE-000000120       432
# 2  1-GDS-HYGIE-000000119       228
# 3  1-GDS-HYGIE-000000152      1200
# 4  1-GDS-HYGIE-000000040      1480

# %%
df_vendor = pd.read_excel('input/vendor_data.xlsx')
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9

# %%
df_bzb = pd.merge(df_stock, df_item, how='left', on='SKUCode')
df_bzb.head()
# Out:
#                                     OtherDescription                SKUCode  \
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000027
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000090
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000042
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000034
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...  1-GDS-HYGIE-000000058
#
#    Quantity
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12

# %%
stopwords = ['(', ')', '-', '_', '', ' ']

# %%
with open("quantity.json", encoding='utf-8') as js:
    quantity_word_list = json.load(js)

# %%
quantity_words = list(quantity_word_list.keys())

trie = dict_trie(dict_source=quantity_words)

custom_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')

# %%
def quantity_cal (word_quantity):
    qty = 0
    for i in word_quantity:
        if i in quantity_words:
            qty = quantity_word_list[i]
        else:
            qty = 1
    return qty

# %% [markdown]
# ## Tokenize Vendor Table

# %%
# Normalize text
df_vendor['Vendor_Name_Clean01'] = df_vendor.apply(lambda row: normalize(row['ProductName']), axis=1)
 
# Word segmentation
df_vendor['Vendor_Name_Clean02'] = df_vendor.apply(lambda row: custom_tokenizer.word_tokenize(row['Vendor_Name_Clean01']), axis=1)
 
# Remove stopwords
df_vendor['Vendor_Name_Clean03'] = df_vendor.apply(lambda row: " ".join([i for i in row['Vendor_Name_Clean02'] if i not in stopwords]), axis=1)

# Calculate Quantity to match BZB table
df_vendor['BZB_Qty'] = df_vendor['Qty']/df_vendor['Vendor_Name_Clean02'].apply(quantity_cal)
df_vendor['BZB_Qty'] = df_vendor['BZB_Qty'].astype(int)

# %%
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight  \
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9
#
#                Vendor_Name_Clean01  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                  Vendor_Name_Clean02  \
# 0               [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1  [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2  [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3  [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4     [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
#
#                 Vendor_Name_Clean03  BZB_Qty
# 0            วิกซอล โกลด์ 900 (2+1)        4
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2     วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3      วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4      วิช ถูพื้น เนเจอร์ ชมพู 5200        4

# %%
df_vendor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ProductCode          50 non-null     int64
#  1   ProductName          50 non-null     object
#  2   Qty                  50 non-null     int64
#  3   Pack                 50 non-null     int64
#  4   Weight               50 non-null     float64
#  5   Vendor_Name_Clean01  50 non-null     object
#  6   Vendor_Name_Clean02  50 non-null     object
#  7   Vendor_Name_Clean03  50 non-null     object
#  8   BZB_Qty              50 non-null     int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 3.6+ KB

# %% [markdown]
# ## Tokenize BZB Table

# %%
# Normalize text
df_bzb['BZB_Name_Clean01'] = df_bzb.apply(lambda row: normalize(row['OtherDescription']), axis=1)
 
# Word segmentation
df_bzb['BZB_Name_Clean02'] = df_bzb.apply(lambda row: custom_tokenizer.word_tokenize(row['BZB_Name_Clean01']), axis=1)
 
# Remove stopwords
df_bzb['BZB_Name_Clean03'] = df_bzb.apply(lambda row: " ".join([i for i in row['BZB_Name_Clean02'] if i not in stopwords]), axis=1)

# %%
df_bzb.head()
# Out:
#                                     OtherDescription                SKUCode  \
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000027
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000090
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000042
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000034
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...  1-GDS-HYGIE-000000058
#
#    Quantity                                   BZB_Name_Clean01  \
# 0        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 1        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 2        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 3        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 4        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...
#
#                                     BZB_Name_Clean02  \
# 0  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เนเจอ...
# 1  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , น้ำยาปรับ...
# 2  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , น้ำยาปรับ...
# 3  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เนเจอ...
# 4  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เซ้นท...
#
#                                     BZB_Name_Clean03
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...

# %%
def concatenate_matching_indices(dfA, dfB, colA, colB):
    """
    Compare specific columns in two DataFrames and return tableA with an additional column
    that contains the indices from tableB that match the value of each row in tableA.
    
    Parameters:
    - tableA: The first DataFrame
    - colA: The name of the column in the first DataFrame to compare
    - tableB: The second DataFrame
    - colB: The name of the column in the second DataFrame to compare
    
    Returns:
    - A DataFrame with an additional column 'matching_indices' containing lists of matching indices in tableB
    """
    if colA not in dfA.columns:
        raise ValueError(f"Column '{colA}' not found in tableA")
    if colB not in dfB.columns:
        raise ValueError(f"Column '{colB}' not found in tableB")
    
    matching_indices = []
    
    for valueA in dfA[colA]:
        matching_indices.append(dfB.index[dfB[colB] == valueA].tolist())
    
    dfA['matching_indices'] = matching_indices
    return dfA

# %%
concatenate_matching_indices(df_vendor, df_bzb, 'BZB_Qty', 'Quantity')
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight  \
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9
#
#                Vendor_Name_Clean01  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                  Vendor_Name_Clean02  \
# 0               [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1  [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2  [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3  [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4     [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
#
#                 Vendor_Name_Clean03  BZB_Qty  \
# 0            วิกซอล โกลด์ 900 (2+1)        4
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2     วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3      วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4      วิช ถูพื้น เนเจอร์ ชมพู 5200        4
#
#                                     matching_indices
# 0                   [27, 28, 29, 30, 31, 32, 37, 48]
# 1                   [27, 28, 29, 30, 31, 32, 37, 48]
# 2  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 3  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 4                   [27, 28, 29, 30, 31, 32, 37, 48]

# %%
df_vendor
# Out:
#     ProductCode                                 ProductName   Qty  Pack  \
# 0    1101155228                      วิกซอล โกลด์ 900 (2+1)    12     1
# 1    1102043121             วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S    12     1
# 2    1201033318               วิช-ถูพื้น ทรีดี ชมพู 650 ซอง    12     1
# 3    1201053312                วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง    12     1
# 4    1201133155                วิช-ถูพื้น เนเจอร์ ชมพู 5200     4     1
# 5    1301033361                        ไฮยีน-บลีช ชมพู 1500     6     1
# 6    1302043299                        ไฮยีน-บลีชผ้าสี 1000    12     1
# 7    1303053559                  ไฮยีน ปากกาขจัดคราบ ฟ้า 10    24     2
# 8    1307023536          ไฮยีน ซักผ้า ฟอร์เอเวอร์ บลูม 1400     8     1
# 9    1307033724                    ไฮยีนซักผ้า เลิฟลี่ 2800     8     2
# 10   1307034472             ไฮยีนซักผ้า เลิฟลี่ 600 แพ็คคู่    12     1
# 11   1307054470              ไฮยีนซักผ้า ซันคิส 600 แพ็คคู่    12     1
# 12   1307134477      ไฮยีนซักผ้า เนเจอร์ซันไรส์ 600 แพ็คคู่    12     1
# 13   1307164215            ไฮยีนซักผ้า มิราเคิล 600 แพ็คคู่    12     1
# 14   1307223430         ไฮยีนซักผ้า กันสีตก บูเก้ เฟรช 1300  3000   375
# 15   1315013704                  ไฮยีน-ปรับผ้านุ่ม ขาว 2800     4     1
# 16   1315023716                  ไฮยีน-ปรับผ้านุ่ม แดง 2800     4     1
# 17   1315033715                 ไฮยีน-ปรับผ้านุ่ม ชมพู 2800     4     1
# 18   1315053709                  ไฮยีน-ปรับผ้านุ่ม ฟ้า 2800     4     1
# 19   1315133723              ไฮยีน-ปรับผ้านุ่ม บานเย็น 2800     4     1
# 20   1316013899            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100    12     1
# 21   1316013931           ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 2000  6000  1500
# 22   1316013955            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว3300  1480   370
# 23   1316014924    ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100 แพ็คคู่   864    72
# 24   1316063904              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม1100    12     1
# 25   1316063937             ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 2200     8     2
# 26   1316063950              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม3300   132    33
# 27   1316133907           ไฮยีนปรับเข้มข้น บลูมมิ่งชมพู1100    12     1
# 28   1317033902        ไฮยีนปรับเข้มข้นไลฟ์ เลิฟลี่ชมพู1100    12     1
# 29   1317093950          ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ 3300   132    33
# 30   1317094919    ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ1100แพ็คคู่  2400   200
# 31   1317143952         ไฮยีนปรับเข้มข้นไลฟ์ ซันดิสอควา3300    76     4
# 32   1317163191      ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิลโรสโกล115  1480   185
# 33   1317164206    ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิล1100แพ็คคู่   132    11
# 34   1318013899               ไฮยีนปรับเข้มข้น สปริงขาว1100    12     1
# 35   1318033905         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100    12     1
# 36   1318033951         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู3300    96     4
# 37   1318034919  ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100แพ็คคู่  2160   180
# 38   1318073903       ไฮยีนปรับเข้มข้น มอร์นิ่งบลูมม่วง1150   464    58
# 39   1319173901       ไฮยีนปรับเข้มข้น ดิลิเชียสมิ้นท์ 1100    12     1
# 40   1319174925  ไฮยีนปรับเข้มข้นดิลิเชียสมิ้นท์ 100แพ็คคู่    12     1
# 41   1319183904         ไฮยีนปรับเข้มข้น ดิลิเชียสชมพู 1100    12     1
# 42   1319184928    ไฮยีนปรับเข้มข้นดิลิเชียสชมพู1100แพ็คคู่   456    38
# 43   1319233258       ไฮยีนปรับเข้มข้น ฟอร์เอเวอร์ชมพู 1100   132    11
# 44   1330183207            ไฮยีน-ถุงหอม ซันไรส์ ชมพู 8 กรัม    24     1
# 45   1601303028      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ออริจินอล 1    48     1
# 46   1601313158      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ลิ้นจี่ 180    48     1
# 47   1601333127     ไอวี่นมเปรี้ยวยูเอชทีพลัส สตอเบอร์รี่ เ    48     1
# 48   1601343097          ไอวี่ นมเปรี้ยวยูเอชทีพลัส ส้ม 180    48     1
# 49   1601443493    ไอวี่นมเปรี้ยวยูเอชทีมิกซ์เบอร์รี่&แครนเ    48     1
#
#     Weight                         Vendor_Name_Clean01  \
# 0    12.50                      วิกซอล โกลด์ 900 (2+1)
# 1     9.80             วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2     8.50               วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     8.50                วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4    21.90                วิช-ถูพื้น เนเจอร์ ชมพู 5200
# 5    11.20                        ไฮยีน-บลีช ชมพู 1500
# 6    13.90                        ไฮยีน-บลีชผ้าสี 1000
# 7     0.60                  ไฮยีน ปากกาขจัดคราบ ฟ้า 10
# 8    12.40          ไฮยีน ซักผ้า ฟอร์เอเวอร์ บลูม 1400
# 9    25.40                    ไฮยีนซักผ้า เลิฟลี่ 2800
# 10    8.00             ไฮยีนซักผ้า เลิฟลี่ 600 แพ็คคู่
# 11    8.00              ไฮยีนซักผ้า ซันคิส 600 แพ็คคู่
# 12    8.00      ไฮยีนซักผ้า เนเจอร์ซันไรส์ 600 แพ็คคู่
# 13    8.00            ไฮยีนซักผ้า มิราเคิล 600 แพ็คคู่
# 14   11.60         ไฮยีนซักผ้า กันสีตก บูเก้ เฟรช 1300
# 15   12.20                  ไฮยีน-ปรับผ้านุ่ม ขาว 2800
# 16   12.20                  ไฮยีน-ปรับผ้านุ่ม แดง 2800
# 17   12.20                 ไฮยีน-ปรับผ้านุ่ม ชมพู 2800
# 18   12.20                  ไฮยีน-ปรับผ้านุ่ม ฟ้า 2800
# 19   12.20              ไฮยีน-ปรับผ้านุ่ม บานเย็น 2800
# 20   14.40            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100
# 21    8.70           ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 2000
# 22   14.50            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว3300
# 23   14.40    ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100 แพ็คคู่
# 24   14.40              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม1100
# 25    9.50             ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 2200
# 26   14.50              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม3300
# 27   14.40           ไฮยีนปรับเข้มข้น บลูมมิ่งชมพู1100
# 28   14.40        ไฮยีนปรับเข้มข้นไลฟ์ เลิฟลี่ชมพู1100
# 29   14.50          ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ 3300
# 30   14.40    ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ1100แพ็คคู่
# 31   14.50         ไฮยีนปรับเข้มข้นไลฟ์ ซันดิสอควา3300
# 32   10.00      ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิลโรสโกล115
# 33   14.40    ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิล1100แพ็คคู่
# 34   14.40               ไฮยีนปรับเข้มข้น สปริงขาว1100
# 35   14.40         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100
# 36   14.50         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู3300
# 37   14.40  ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100แพ็คคู่
# 38   10.00       ไฮยีนปรับเข้มข้น มอร์นิ่งบลูมม่วง1150
# 39   14.40       ไฮยีนปรับเข้มข้น ดิลิเชียสมิ้นท์ 1100
# 40   14.40  ไฮยีนปรับเข้มข้นดิลิเชียสมิ้นท์ 100แพ็คคู่
# 41   14.30         ไฮยีนปรับเข้มข้น ดิลิเชียสชมพู 1100
# 42   14.40    ไฮยีนปรับเข้มข้นดิลิเชียสชมพู1100แพ็คคู่
# 43   14.40       ไฮยีนปรับเข้มข้น ฟอร์เอเวอร์ชมพู 1100
# 44    0.41            ไฮยีน-ถุงหอม ซันไรส์ ชมพู 8 กรัม
# 45    9.94      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ออริจินอล 1
# 46    9.94      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ลิ้นจี่ 180
# 47    9.94     ไอวี่นมเปรี้ยวยูเอชทีพลัส สตอเบอร์รี่ เ
# 48    9.94          ไอวี่ นมเปรี้ยวยูเอชทีพลัส ส้ม 180
# 49    8.21    ไอวี่นมเปรี้ยวยูเอชทีมิกซ์เบอร์รี่&แครนเ
#
#                                   Vendor_Name_Clean02  \
# 0                [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1   [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2   [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3   [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4      [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
# 5                  [ไฮยีน, -, บลีช,  , ชมพู,  , 1500]
# 6                      [ไฮยีน, -, บลีชผ้าสี,  , 1000]
# 7            [ไฮยีน,  , ปากกาขจัดคราบ,  , ฟ้า,  , 10]
# 8   [ไฮยีน,  , ซักผ้า,  , ฟอร์เอเวอร์,  , บลูม,  ,...
# 9                  [ไฮยีนซักผ้า,  , เลิฟลี่,  , 2800]
# 10      [ไฮยีนซักผ้า,  , เลิฟลี่,  , 600,  , แพ็คคู่]
# 11       [ไฮยีนซักผ้า,  , ซันคิส,  , 600,  , แพ็คคู่]
# 12  [ไฮยีนซักผ้า,  , เนเจอร์ซันไรส์,  , 600,  , แพ...
# 13     [ไฮยีนซักผ้า,  , มิราเคิล,  , 600,  , แพ็คคู่]
# 14  [ไฮยีนซักผ้า,  , กันสีตก,  , บูเก้,  , เฟรช,  ...
# 15           [ไฮยีน, -, ปรับผ้านุ่ม,  , ขาว,  , 2800]
# 16           [ไฮยีน, -, ปรับผ้านุ่ม,  , แดง,  , 2800]
# 17          [ไฮยีน, -, ปรับผ้านุ่ม,  , ชมพู,  , 2800]
# 18           [ไฮยีน, -, ปรับผ้านุ่ม,  , ฟ้า,  , 2800]
# 19       [ไฮยีน, -, ปรับผ้านุ่ม,  , บานเย็น,  , 2800]
# 20           [ไฮยีนปรับเข้มข้น,  , มิลค์กี้ขาว, 1100]
# 21        [ไฮยีนปรับเข้มข้น,  , มิลค์กี้ขาว,  , 2000]
# 22           [ไฮยีนปรับเข้มข้น,  , มิลค์กี้ขาว, 3300]
# 23  [ไฮยีนปรับเข้มข้น,  , มิลค์กี้ขาว, 1100,  , แพ...
# 24             [ไฮยีนปรับเข้มข้น,  , แฮปปี้ส้ม, 1100]
# 25          [ไฮยีนปรับเข้มข้น,  , แฮปปี้ส้ม,  , 2200]
# 26             [ไฮยีนปรับเข้มข้น,  , แฮปปี้ส้ม, 3300]
# 27          [ไฮยีนปรับเข้มข้น,  , บลูมมิ่งชมพู, 1100]
# 28       [ไฮยีนปรับเข้มข้นไลฟ์,  , เลิฟลี่ชมพู, 1100]
# 29       [ไฮยีนปรับเข้มข้นไลฟ์,  , พีโอนีดำ,  , 3300]
# 30  [ไฮยีนปรับเข้มข้นไลฟ์,  , พีโอนีดำ, 1100, แพ็ค...
# 31        [ไฮยีนปรับเข้มข้นไลฟ์,  , ซันดิสอควา, 3300]
# 32     [ไฮยีนปรับเข้มข้นไลฟ์,  , มิราเคิลโรสโกล, 115]
# 33  [ไฮยีนปรับเข้มข้นไลฟ์,  , มิราเคิล, 1100, แพ็ค...
# 34              [ไฮยีนปรับเข้มข้น,  , สปริงขาว, 1100]
# 35        [ไฮยีนปรับเข้มข้น,  , ซันไรส์คิสชมพู, 1100]
# 36        [ไฮยีนปรับเข้มข้น,  , ซันไรส์คิสชมพู, 3300]
# 37  [ไฮยีนปรับเข้มข้น,  , ซันไรส์คิสชมพู, 1100, แพ...
# 38      [ไฮยีนปรับเข้มข้น,  , มอร์นิ่งบลูมม่วง, 1150]
# 39    [ไฮยีนปรับเข้มข้น,  , ดิลิเชียสมิ้นท์,  , 1100]
# 40  [ไฮยีนปรับเข้มข้นดิลิเชียสมิ้นท์,  , 100, แพ็ค...
# 41      [ไฮยีนปรับเข้มข้น,  , ดิลิเชียสชมพู,  , 1100]
# 42     [ไฮยีนปรับเข้มข้นดิลิเชียสชมพู, 1100, แพ็คคู่]
# 43    [ไฮยีนปรับเข้มข้น,  , ฟอร์เอเวอร์ชมพู,  , 1100]
# 44  [ไฮยีน, -, ถุงหอม,  , ซันไรส์,  , ชมพู,  , 8, ...
# 45  [ไอวี่,  , นมเปรี้ยวยูเอชทีพลัส,  , ออริจินอล,...
# 46  [ไอวี่,  , นมเปรี้ยวยูเอชทีพลัส,  , ลิ้นจี่,  ...
# 47  [ไอวี่นมเปรี้ยวยูเอชทีพลัส,  , สตอเบอร์รี่,  , เ]
# 48   [ไอวี่,  , นมเปรี้ยวยูเอชทีพลัส,  , ส้ม,  , 180]
# 49     [ไอวี่นมเปรี้ยวยูเอชทีมิกซ์เบอร์รี่, &, แครนเ]
#
#                              Vendor_Name_Clean03  BZB_Qty  \
# 0                         วิกซอล โกลด์ 900 (2+1)        4
# 1               วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2                  วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3                   วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4                   วิช ถูพื้น เนเจอร์ ชมพู 5200        4
# 5                           ไฮยีน บลีช ชมพู 1500        6
# 6                           ไฮยีน บลีชผ้าสี 1000       12
# 7                     ไฮยีน ปากกาขจัดคราบ ฟ้า 10       24
# 8             ไฮยีน ซักผ้า ฟอร์เอเวอร์ บลูม 1400        8
# 9                       ไฮยีนซักผ้า เลิฟลี่ 2800        8
# 10               ไฮยีนซักผ้า เลิฟลี่ 600 แพ็คคู่        6
# 11                ไฮยีนซักผ้า ซันคิส 600 แพ็คคู่        6
# 12        ไฮยีนซักผ้า เนเจอร์ซันไรส์ 600 แพ็คคู่        6
# 13              ไฮยีนซักผ้า มิราเคิล 600 แพ็คคู่        6
# 14           ไฮยีนซักผ้า กันสีตก บูเก้ เฟรช 1300     3000
# 15                    ไฮยีน ปรับผ้านุ่ม ขาว 2800        4
# 16                    ไฮยีน ปรับผ้านุ่ม แดง 2800        4
# 17                   ไฮยีน ปรับผ้านุ่ม ชมพู 2800        4
# 18                    ไฮยีน ปรับผ้านุ่ม ฟ้า 2800        4
# 19                ไฮยีน ปรับผ้านุ่ม บานเย็น 2800        4
# 20             ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 1100       12
# 21             ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 2000     6000
# 22             ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 3300     1480
# 23     ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 1100 แพ็คคู่      432
# 24               ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 1100       12
# 25               ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 2200        8
# 26               ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 3300      132
# 27            ไฮยีนปรับเข้มข้น บลูมมิ่งชมพู 1100       12
# 28         ไฮยีนปรับเข้มข้นไลฟ์ เลิฟลี่ชมพู 1100       12
# 29            ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ 3300      132
# 30    ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ 1100 แพ็คคู่     1200
# 31          ไฮยีนปรับเข้มข้นไลฟ์ ซันดิสอควา 3300       76
# 32       ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิลโรสโกล 115     1480
# 33    ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิล 1100 แพ็คคู่       66
# 34                ไฮยีนปรับเข้มข้น สปริงขาว 1100       12
# 35          ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู 1100       12
# 36          ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู 3300       96
# 37  ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู 1100 แพ็คคู่     1080
# 38        ไฮยีนปรับเข้มข้น มอร์นิ่งบลูมม่วง 1150      464
# 39         ไฮยีนปรับเข้มข้น ดิลิเชียสมิ้นท์ 1100       12
# 40   ไฮยีนปรับเข้มข้นดิลิเชียสมิ้นท์ 100 แพ็คคู่        6
# 41           ไฮยีนปรับเข้มข้น ดิลิเชียสชมพู 1100       12
# 42    ไฮยีนปรับเข้มข้นดิลิเชียสชมพู 1100 แพ็คคู่      228
# 43         ไฮยีนปรับเข้มข้น ฟอร์เอเวอร์ชมพู 1100      132
# 44              ไฮยีน ถุงหอม ซันไรส์ ชมพู 8 กรัม       24
# 45        ไอวี่ นมเปรี้ยวยูเอชทีพลัส ออริจินอล 1       48
# 46        ไอวี่ นมเปรี้ยวยูเอชทีพลัส ลิ้นจี่ 180       48
# 47       ไอวี่นมเปรี้ยวยูเอชทีพลัส สตอเบอร์รี่ เ       48
# 48            ไอวี่ นมเปรี้ยวยูเอชทีพลัส ส้ม 180       48
# 49    ไอวี่นมเปรี้ยวยูเอชทีมิกซ์เบอร์รี่ & แครนเ       48
#
#                                      matching_indices
# 0                    [27, 28, 29, 30, 31, 32, 37, 48]
# 1                    [27, 28, 29, 30, 31, 32, 37, 48]
# 2   [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 3   [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 4                    [27, 28, 29, 30, 31, 32, 37, 48]
# 5                            [23, 35, 38, 39, 40, 41]
# 6   [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 7                                            [47, 49]
# 8                                        [10, 24, 45]
# 9                                        [10, 24, 45]
# 10                           [23, 35, 38, 39, 40, 41]
# 11                           [23, 35, 38, 39, 40, 41]
# 12                           [23, 35, 38, 39, 40, 41]
# 13                           [23, 35, 38, 39, 40, 41]
# 14                                               [46]
# 15                   [27, 28, 29, 30, 31, 32, 37, 48]
# 16                   [27, 28, 29, 30, 31, 32, 37, 48]
# 17                   [27, 28, 29, 30, 31, 32, 37, 48]
# 18                   [27, 28, 29, 30, 31, 32, 37, 48]
# 19                   [27, 28, 29, 30, 31, 32, 37, 48]
# 20  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 21                                               [26]
# 22                                               [18]
# 23                                               [34]
# 24  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 25                                       [10, 24, 45]
# 26                                       [11, 14, 44]
# 27  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 28  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 29                                       [11, 14, 44]
# 30                                               [42]
# 31                                               [12]
# 32                                               [18]
# 33                                               [43]
# 34  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 35  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 36                                               [13]
# 37                                               [33]
# 38                                                [6]
# 39  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 40                           [23, 35, 38, 39, 40, 41]
# 41  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...
# 42                                               [36]
# 43                                       [11, 14, 44]
# 44                                           [47, 49]
# 45                                                 []
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49                                                 []

# %%
def calculate_max_cosine_similarity(tableA, colA, tableB, colB, match_col, return_col):
    """
    Calculate the cosine similarity between text in tableA and tableB based on matching indices,
    and concatenate the maximum cosine similarity and corresponding value from tableB to tableA.
    
    Parameters:
    - tableA: The first DataFrame
    - colA: The name of the text column in the first DataFrame
    - tableB: The second DataFrame
    - colB: The name of the text column in the second DataFrame
    - match_col: The name of the column in tableA containing the matching indices
    - return_col: The name of the column in tableB from which to return the value corresponding to the max similarity
    
    Returns:
    - A DataFrame with additional columns 'max_cosine_similarity' and the specified return column value
    """
    # Ensure the matching column exists in tableA
    if match_col not in tableA.columns:
        raise ValueError(f"Column '{match_col}' not found in tableA")
    
    # Ensure the return column exists in tableB
    if return_col not in tableB.columns:
        raise ValueError(f"Column '{return_col}' not found in tableB")

    max_similarities = []
    return_values = []
    vectorizer = TfidfVectorizer()

    for index, row in tableA.iterrows():
        matching_indices = row[match_col]
        textA = row[colA]
        
        if not matching_indices:  # If matching_indices is an empty list
            textsB = tableB[colB].tolist()
            return_values_full = tableB[return_col].tolist()
        else:
            textsB = tableB.loc[matching_indices, colB].tolist()
            return_values_full = tableB.loc[matching_indices, return_col].tolist()

        # Combine the text from tableA and matching texts from tableB for vectorization
        all_texts = [textA] + textsB
        tfidf_matrix = vectorizer.fit_transform(all_texts)

        # Calculate cosine similarities with the first row being the text from tableA
        cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
        
        # Get the maximum cosine similarity and the corresponding value from tableB
        max_similarity_index = cosine_sim.argmax()
        max_similarity = cosine_sim.max()
        max_return_value = return_values_full[max_similarity_index]
        
        max_similarities.append(max_similarity)
        return_values.append(max_return_value)
    
    tableA['max_cosine_similarity'] = max_similarities
    tableA[f'return_{return_col}'] = return_values
    return tableA

# %%
calculate_max_cosine_similarity(df_vendor, 'Vendor_Name_Clean03', df_bzb, 'BZB_Name_Clean03', 'matching_indices', 'SKUCode')
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight  \
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9
#
#                Vendor_Name_Clean01  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                  Vendor_Name_Clean02  \
# 0               [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1  [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2  [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3  [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4     [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
#
#                 Vendor_Name_Clean03  BZB_Qty  \
# 0            วิกซอล โกลด์ 900 (2+1)        4
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2     วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3      วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4      วิช ถูพื้น เนเจอร์ ชมพู 5200        4
#
#                                     matching_indices  max_cosine_similarity  \
# 0                   [27, 28, 29, 30, 31, 32, 37, 48]               0.482393
# 1                   [27, 28, 29, 30, 31, 32, 37, 48]               0.296545
# 2  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.198344
# 3  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.135273
# 4                   [27, 28, 29, 30, 31, 32, 37, 48]               0.139477
#
#           return_SKUCode
# 0  1-GDS-VIXOL-000000014
# 1  1-GDS-VIXOL-000000025
# 2  1-GDS-WHIZ0-000000004
# 3  1-GDS-WHIZ0-000000005
# 4  1-GDS-HYGIE-000000110

# %%
def recalculate_similarity_if_below_threshold(tableA, colA, tableB, colB, match_col, threshold, return_col):
    """
    Recalculate the cosine similarity for rows in tableA where max_cosine_similarity is below the threshold.
    Compare the text in tableA with all text in tableB instead of just matching indices.
    Update tableA with the maximum cosine similarity and a new value from tableB.

    Parameters:
    - tableA: The first DataFrame
    - colA: The name of the text column in the first DataFrame
    - tableB: The second DataFrame
    - colB: The name of the text column in the second DataFrame
    - match_col: The name of the column in tableA containing the matching indices
    - threshold: The threshold value below which to recalculate the cosine similarity
    - return_col: The name of the column in tableB from which to return the value corresponding to the max similarity
    
    Returns:
    - A DataFrame with updated 'max_cosine_similarity' values and the new return column value
    """
    # Ensure the matching column exists in tableA
    if match_col not in tableA.columns:
        raise ValueError(f"Column '{match_col}' not found in tableA")
    
    # Ensure the columns exist in both DataFrames
    if colA not in tableA.columns:
        raise ValueError(f"Column '{colA}' not found in tableA")
    if colB not in tableB.columns:
        raise ValueError(f"Column '{colB}' not found in tableB")
    if return_col not in tableB.columns:
        raise ValueError(f"Column '{return_col}' not found in tableB")

    # Get the rows where the current max_cosine_similarity is below the threshold
    rows_to_recalculate = tableA[tableA['max_cosine_similarity'] < threshold].index
    
    vectorizer = TfidfVectorizer()
    
    for index in rows_to_recalculate:
        row = tableA.loc[index]
        textA = row[colA]
        
        # Recalculate with all texts from tableB
        textsB = tableB[colB].tolist()
        return_values_full = tableB[return_col].tolist()
        tfidf_matrix = vectorizer.fit_transform([textA] + textsB)

        # Calculate cosine similarities with the first row being the text from tableA
        cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
        
        # Get the new maximum cosine similarity and the corresponding value from tableB
        max_similarity_index = cosine_sim.argmax()
        new_max_similarity = cosine_sim.max()
        max_return_value = return_values_full[max_similarity_index]
        
        # Update the tableA DataFrame
        tableA.at[index, 'max_cosine_similarity'] = new_max_similarity
        tableA.at[index, f'return_{return_col}'] = max_return_value
    
    return tableA

# %%
recalculate_similarity_if_below_threshold(df_vendor, 'Vendor_Name_Clean03', df_bzb, 'BZB_Name_Clean03', 'matching_indices', 0.1, 'SKUCode')
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight  \
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9
#
#                Vendor_Name_Clean01  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                  Vendor_Name_Clean02  \
# 0               [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1  [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2  [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3  [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4     [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
#
#                 Vendor_Name_Clean03  BZB_Qty  \
# 0            วิกซอล โกลด์ 900 (2+1)        4
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2     วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3      วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4      วิช ถูพื้น เนเจอร์ ชมพู 5200        4
#
#                                     matching_indices  max_cosine_similarity  \
# 0                   [27, 28, 29, 30, 31, 32, 37, 48]               0.482393
# 1                   [27, 28, 29, 30, 31, 32, 37, 48]               0.296545
# 2  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.198344
# 3  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.135273
# 4                   [27, 28, 29, 30, 31, 32, 37, 48]               0.139477
#
#           return_SKUCode
# 0  1-GDS-VIXOL-000000014
# 1  1-GDS-VIXOL-000000025
# 2  1-GDS-WHIZ0-000000004
# 3  1-GDS-WHIZ0-000000005
# 4  1-GDS-HYGIE-000000110

# %%
df_bzb.head()
# Out:
#                                     OtherDescription                SKUCode  \
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000027
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000090
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...  1-GDS-HYGIE-000000042
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...  1-GDS-HYGIE-000000034
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...  1-GDS-HYGIE-000000058
#
#    Quantity                                   BZB_Name_Clean01  \
# 0        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 1        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 2        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 3        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 4        12  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...
#
#                                     BZB_Name_Clean02  \
# 0  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เนเจอ...
# 1  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , น้ำยาปรับ...
# 2  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , น้ำยาปรับ...
# 3  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เนเจอ...
# 4  [ไฮยีน,  , เอ็กซ์เพิร์ท,  , แคร์,  , ไลฟ์เซ้นท...
#
#                                     BZB_Name_Clean03
# 0  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 1  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 2  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...
# 3  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...
# 4  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...

# %%
df_vendor = df_vendor.merge(df_bzb[['OtherDescription', 'SKUCode']], how='left', left_on='return_SKUCode', right_on='SKUCode')
df_vendor.head()
# Out:
#    ProductCode                      ProductName  Qty  Pack  Weight  \
# 0   1101155228           วิกซอล โกลด์ 900 (2+1)   12     1    12.5
# 1   1102043121  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S   12     1     9.8
# 2   1201033318    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง   12     1     8.5
# 3   1201053312     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง   12     1     8.5
# 4   1201133155     วิช-ถูพื้น เนเจอร์ ชมพู 5200    4     1    21.9
#
#                Vendor_Name_Clean01  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                  Vendor_Name_Clean02  \
# 0               [วิกซอล,  , โกลด์,  , 900,  , (2+1)]
# 1  [วิกซอล,  , ออกซี่,  , มิ้นท์,  , 700,  , มล, ...
# 2  [วิช, -, ถูพื้น,  , ทรีดี,  , ชมพู,  , 650,  ,...
# 3  [วิช, -, ถูพื้น,  , ทรีดี,  , ฟ้า,  , 650,  , ...
# 4     [วิช, -, ถูพื้น,  , เนเจอร์,  , ชมพู,  , 5200]
#
#                 Vendor_Name_Clean03  BZB_Qty  \
# 0            วิกซอล โกลด์ 900 (2+1)        4
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล . 3S        4
# 2     วิช ถูพื้น ทรีดี ชมพู 650 ซอง       12
# 3      วิช ถูพื้น ทรีดี ฟ้า 650 ซอง       12
# 4      วิช ถูพื้น เนเจอร์ ชมพู 5200        4
#
#                                     matching_indices  max_cosine_similarity  \
# 0                   [27, 28, 29, 30, 31, 32, 37, 48]               0.482393
# 1                   [27, 28, 29, 30, 31, 32, 37, 48]               0.296545
# 2  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.198344
# 3  [0, 1, 2, 3, 4, 5, 7, 8, 9, 16, 17, 19, 20, 21...               0.135273
# 4                   [27, 28, 29, 30, 31, 32, 37, 48]               0.139477
#
#           return_SKUCode                                   OtherDescription  \
# 0  1-GDS-VIXOL-000000014  วิกซอล โกลด์ นำยาล้างห้องน้ำและสุขภัณฑ์ 900 มล...
# 1  1-GDS-VIXOL-000000025  วิกซอล ออกซี่ ผลิตภัณฑ์ล้างห้องน้ำและสุขภัณฑ์ ...
# 2  1-GDS-WHIZ0-000000004  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...
# 3  1-GDS-WHIZ0-000000005  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...
# 4  1-GDS-HYGIE-000000110  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น พิ...
#
#                  SKUCode
# 0  1-GDS-VIXOL-000000014
# 1  1-GDS-VIXOL-000000025
# 2  1-GDS-WHIZ0-000000004
# 3  1-GDS-WHIZ0-000000005
# 4  1-GDS-HYGIE-000000110

# %%
resulted_df = df_vendor.copy()
resulted_df = resulted_df[['ProductName', 'OtherDescription', 'max_cosine_similarity']]
resulted_df.head()
# Out:
#                        ProductName  \
# 0           วิกซอล โกลด์ 900 (2+1)
# 1  วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2    วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3     วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4     วิช-ถูพื้น เนเจอร์ ชมพู 5200
#
#                                     OtherDescription  max_cosine_similarity
# 0  วิกซอล โกลด์ นำยาล้างห้องน้ำและสุขภัณฑ์ 900 มล...               0.482393
# 1  วิกซอล ออกซี่ ผลิตภัณฑ์ล้างห้องน้ำและสุขภัณฑ์ ...               0.296545
# 2  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.198344
# 3  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.135273
# 4  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น พิ...               0.139477

# %%
resulted_df
# Out:
#                                    ProductName  \
# 0                       วิกซอล โกลด์ 900 (2+1)
# 1              วิกซอล ออกซี่ มิ้นท์ 700 มล. 3S
# 2                วิช-ถูพื้น ทรีดี ชมพู 650 ซอง
# 3                 วิช-ถูพื้น ทรีดี ฟ้า 650 ซอง
# 4                 วิช-ถูพื้น เนเจอร์ ชมพู 5200
# 5                         ไฮยีน-บลีช ชมพู 1500
# 6                         ไฮยีน-บลีชผ้าสี 1000
# 7                   ไฮยีน ปากกาขจัดคราบ ฟ้า 10
# 8           ไฮยีน ซักผ้า ฟอร์เอเวอร์ บลูม 1400
# 9                     ไฮยีนซักผ้า เลิฟลี่ 2800
# 10             ไฮยีนซักผ้า เลิฟลี่ 600 แพ็คคู่
# 11              ไฮยีนซักผ้า ซันคิส 600 แพ็คคู่
# 12      ไฮยีนซักผ้า เนเจอร์ซันไรส์ 600 แพ็คคู่
# 13            ไฮยีนซักผ้า มิราเคิล 600 แพ็คคู่
# 14         ไฮยีนซักผ้า กันสีตก บูเก้ เฟรช 1300
# 15                  ไฮยีน-ปรับผ้านุ่ม ขาว 2800
# 16                  ไฮยีน-ปรับผ้านุ่ม แดง 2800
# 17                 ไฮยีน-ปรับผ้านุ่ม ชมพู 2800
# 18                  ไฮยีน-ปรับผ้านุ่ม ฟ้า 2800
# 19              ไฮยีน-ปรับผ้านุ่ม บานเย็น 2800
# 20            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100
# 21           ไฮยีนปรับเข้มข้น มิลค์กี้ขาว 2000
# 22            ไฮยีนปรับเข้มข้น มิลค์กี้ขาว3300
# 23    ไฮยีนปรับเข้มข้น มิลค์กี้ขาว1100 แพ็คคู่
# 24              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม1100
# 25             ไฮยีนปรับเข้มข้น แฮปปี้ส้ม 2200
# 26              ไฮยีนปรับเข้มข้น แฮปปี้ส้ม3300
# 27           ไฮยีนปรับเข้มข้น บลูมมิ่งชมพู1100
# 28        ไฮยีนปรับเข้มข้นไลฟ์ เลิฟลี่ชมพู1100
# 29          ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ 3300
# 30    ไฮยีนปรับเข้มข้นไลฟ์ พีโอนีดำ1100แพ็คคู่
# 31         ไฮยีนปรับเข้มข้นไลฟ์ ซันดิสอควา3300
# 32      ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิลโรสโกล115
# 33    ไฮยีนปรับเข้มข้นไลฟ์ มิราเคิล1100แพ็คคู่
# 34               ไฮยีนปรับเข้มข้น สปริงขาว1100
# 35         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100
# 36         ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู3300
# 37  ไฮยีนปรับเข้มข้น ซันไรส์คิสชมพู1100แพ็คคู่
# 38       ไฮยีนปรับเข้มข้น มอร์นิ่งบลูมม่วง1150
# 39       ไฮยีนปรับเข้มข้น ดิลิเชียสมิ้นท์ 1100
# 40  ไฮยีนปรับเข้มข้นดิลิเชียสมิ้นท์ 100แพ็คคู่
# 41         ไฮยีนปรับเข้มข้น ดิลิเชียสชมพู 1100
# 42    ไฮยีนปรับเข้มข้นดิลิเชียสชมพู1100แพ็คคู่
# 43       ไฮยีนปรับเข้มข้น ฟอร์เอเวอร์ชมพู 1100
# 44            ไฮยีน-ถุงหอม ซันไรส์ ชมพู 8 กรัม
# 45      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ออริจินอล 1
# 46      ไอวี่ นมเปรี้ยวยูเอชทีพลัส ลิ้นจี่ 180
# 47     ไอวี่นมเปรี้ยวยูเอชทีพลัส สตอเบอร์รี่ เ
# 48          ไอวี่ นมเปรี้ยวยูเอชทีพลัส ส้ม 180
# 49    ไอวี่นมเปรี้ยวยูเอชทีมิกซ์เบอร์รี่&แครนเ
#
#                                      OtherDescription  max_cosine_similarity
# 0   วิกซอล โกลด์ นำยาล้างห้องน้ำและสุขภัณฑ์ 900 มล...               0.482393
# 1   วิกซอล ออกซี่ ผลิตภัณฑ์ล้างห้องน้ำและสุขภัณฑ์ ...               0.296545
# 2   วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.198344
# 3   วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.135273
# 4   ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น พิ...               0.139477
# 5   ไฮยีน ผลิตภัณฑ์ขจัดคราบสำหรับผ้าขาว สีชมพู 150...               0.377137
# 6   ไฮยีน ผลิตภัณฑ์ขจัดคราบสำหรับผ้าขาวและผ้าสี กล...               0.319591
# 7                          ไฮยีน ปากกาขจัดคราบ 10 มล.               0.822039
# 8   ไฮยีน เอ็กซ์เพิร์ท วอช ผลิตภัณฑ์ซักผ้าชนิดน้ำ ...               0.423375
# 9   ไฮยีน เอ็กซ์เพิร์ท วอช ผลิตภัณฑ์ซักผ้าชนิดน้ำ ...               0.302345
# 10  [แพ็คสุดคุ้ม 1+1] ไฮยีนซักผ้า กลิ่นเลิฟลี่ บลู...               0.461593
# 11  [แพ็คสุดคุ้ม 1+1] ไฮยีนซักผ้า กลิ่นซันคิส บลูม...               0.561597
# 12  [แพ็คสุดคุ้ม 1+1] ไฮยีนซักผ้า กลิ่นซันไรส์ คิส...               0.570866
# 13  [แพ็คสุดคุ้ม 1+1] ไฮยีนซักผ้า กลิ่นมิราเคิล บล...               0.533813
# 14  ไฮยีน เอ็กซ์เพิร์ท วอช ผลิตภัณฑ์ซักผ้าชนิดน้ำ ...               0.318653
# 15  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น ซอ...               0.585490
# 16  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น สว...               0.599937
# 17  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น พิ...               0.583006
# 18  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่น พิ...               0.485366
# 19  ผลิตภัณฑ์ปรับผ้านุ่มสูตรมาตรฐาน ไฮยีน กลิ่นการ...               0.542211
# 20  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.404240
# 21  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.283999
# 22  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.212773
# 23  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน เอ็กซ์เพิร์ท แคร์ มิล...               0.241299
# 24  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.176216
# 25  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.289478
# 26  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.196409
# 27  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.208453
# 28  วิซ 3D ผลิตภัณฑ์ทำความสะอาดพื้นสูตรเข้มข้น กลิ...               0.285816
# 29  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เซ้นท์ น้ำยาปรับผ้...               0.203228
# 30  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ...               0.178566
# 31  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.200129
# 32  [แพ็คสุดคุ้ม 1+1] ไฮยีนซักผ้า กลิ่นมิราเคิล บล...               0.143756
# 33  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ...               0.190853
# 34  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.157708
# 35  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...               0.272726
# 36  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.229312
# 37  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ...               0.220321
# 38  ไฮยีน เอ็กซ์เพิร์ท แคร์ ไลฟ์เนเจอร์ น้ำยาปรับผ...               0.170731
# 39  ไฮยีน ดิลิเชียส ซีรีส์ น้ำยาปรับผ้านุ่มสูตรเข้...               0.267388
# 40  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน ลิมิเท็ด อิดิชั่น ดิล...               0.126365
# 41  ไฮยีน ดิลิเชียส ซีรีส์ น้ำยาปรับผ้านุ่มสูตรเข้...               0.176142
# 42  [แพ็คสุดคุ้ม 1+1 ] ไฮยีน ลิมิเท็ด อิดิชั่น ดิล...               0.215283
# 43  ไฮยีน เอ็กซ์เพิร์ท แคร์ น้ำยาปรับผ้านุ่มสูตรเข...               0.246561
# 44  ไฮยีน ผลิตภัณฑ์ถุงหอม กลิ่นซันไรส์ คิส ขนาด 8 ...               0.417379
# 45  ไอวี่โยเกิร์ตพร้อมดื่ม ยูเอชที รสสตรอเบอรรี่ 1...               0.190254
# 46  ไอวี่โยเกิร์ตพร้อมดื่ม ยูเอชที รสลิ้นจี่ 180มล...               0.442480
# 47  ไอวี่โยเกิร์ตพร้อมดื่ม ยูเอชที รสสตรอเบอรรี่ 1...               0.208425
# 48  ไอวี่โยเกิร์ตพร้อมดื่ม ยูเอชที รสสตรอเบอรรี่ 1...               0.341670
# 49  ไอวี่โยเกิร์ตพร้อมดื่ม ยูเอชที เบอร์รี่ไฟเบอร์...               0.409879

# %%
resulted_df.to_excel("output/resulted_data.xlsx", index=False)
